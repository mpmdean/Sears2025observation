# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib.colors as colors
import matplotlib
import matplotlib.ticker as ticker
import matplotlib as mpl
import matplotlib.colors as col
import matplotlib.cm as cm
from ase.io import read
import copy
import matplotlib.patches as patches

import numpy as np
import scipy as sp
import matplotlib.pyplot as plt
import scipy
from timeit import default_timer as de_time
from pymcaspec import specfile
from matplotlib.patches import Rectangle, FancyBboxPatch

mpl.rc('lines', markersize=3)
colors = [f'C{i}' for i in range(10)]
font = {'size' : 7}
matplotlib.rc('font', **font)

# %%
# Helper functions
def mybin(x,y,yerr, binsize):
    new_x = []
    new_y = []
    new_yerr = []
    index = len(x)
    for i in range(0,index, binsize): #n is index, i is value      
        new_x.append(np.mean(x[i:i+binsize]))
        new_y.append(np.mean(y[i:i+binsize]))
        new_yerr.append(np.sqrt(np.mean(yerr[i:i+binsize]**2)))  
    new_x = np.array(new_x)
    new_y = np.array(new_y)
    new_yerr = np.array(new_yerr)
    
    return new_x, new_y, new_yerr

def rixsDataReader(data_folder, scan, spectrum_name='SPC', xshift = 0, interp=False, x_ref=None, scale = 1, norm=False, 
                   monitor_name='Mirror current / 1e6'): 
    f = specfile(data_folder)
    s = f[scan]
    x = -s['Energy (eV)'][::-1]
    y = s[spectrum_name][::-1]
    
    x = x + xshift
    yerr = np.sqrt(y)

    if interp and isinstance(x_ref, (list, np.ndarray)):
        y = np.interp(x_ref,x,y)
        yerr = np.sqrt(y)
        x = x_ref
    
    if norm:
        norm_factor = s[monitor_name][::-1]
        y = y / norm_factor
        yerr = yerr / norm_factor
        
    y = y * scale
    yerr = yerr * scale
    return x, y, yerr

# %%
import pickle
fname = './edrixs/AIM_RIXS_analysis_update300.pickle'


with open(fname, 'rb') as f:
    xsplit = pickle.load(f)

# Make the figure and subplots
fig = plt.figure(figsize=((3+3/8), 5))
scl1 = 1.3
hh = 0.19*scl1
hh1 = 0.14*scl1
dh = 0.015

dd1 = 0.06
ax1a = fig.add_axes([0.15, dd1+4*dh+hh+2*hh1,0.14,hh])
ax2a = fig.add_axes([0.15, dd1+3*dh+2*hh1,0.14,hh])
ax3a = fig.add_axes([0.15, dd1+2*dh+hh1,0.14,hh1])
ax4a = fig.add_axes([0.15, dd1+dh,0.14,hh1])

ax1 = fig.add_axes([0.3, dd1+4*dh+hh+2*hh1,0.67,hh])
ax2 = fig.add_axes([0.3, dd1+3*dh+2*hh1,0.67,hh])
ax3 = fig.add_axes([0.3, dd1+2*dh+hh1,0.67,hh1])
ax4 = fig.add_axes([0.3, dd1+dh,0.67,hh1])

# Plot RIXS simulation in the top panel 
rixs_sim = xsplit
rixsy = rixs_sim['rixs_lh'][0][0]/40+ rixs_sim['rixs_lh_at2'][0][0]/40
ax2.plot(rixs_sim['eloss'], rixsy, color='firebrick', label='$\pi$ simulation', linewidth=0.6)
ax2a.plot(rixs_sim['eloss'], rixsy, color='firebrick', label='$\pi$ simulation', linewidth=0.6)

rixsy = rixs_sim['rixs_lv'][0][0]/40+ rixs_sim['rixs_lv_at2'][0][0]/40
ax2.plot(rixs_sim['eloss'], rixsy, color='darkslategray', label='$\sigma$ simulation', linewidth=0.6, ls='dashed')
ax2a.plot(rixs_sim['eloss'], rixsy, color='darkslategray', label='$\sigma$ simulation', linewidth=0.6, ls='dashed')

# Plot the RIXS experimental data in the second panel
f = specfile('./Online_analysis_20220913_CrSBr_5_00_dir.spec')
datafolder = './Online_analysis_20220913_CrSBr_5_00_dir.spec'
# LH, Ein=577.4 eV, zero shift adjusted by hand
scan = 88
s = f[scan]
x0,y0,yerr = rixsDataReader(datafolder, scan, xshift=-0.022 , norm=True)  
x0,y0,yerr = mybin(x0, y0, yerr, 8)
norm = np.average(s['Mirror current / 1e6'][::-1])/5400
ax1.errorbar(x0, y0*norm, yerr*norm, color='firebrick', label='$\pi$ data', marker='o', mfc='None', linewidth=0.6)
ax1a.errorbar(x0, y0*norm, yerr*norm, color='firebrick', label='$\pi$ data', marker='o', mfc='None', linewidth=0.6)

# LV, Ein=577.4 eV, zero shift adjusted by hand
scan = 99
s = f[scan]
x0,y0,yerr = rixsDataReader(datafolder, scan, xshift=-0.017 , norm=True)  
x0,y0,yerr = mybin(x0, y0, yerr, 8)
norm = np.average(s['Mirror current / 1e6'][::-1])/5400
ax1.errorbar(x0, y0*norm, yerr*norm, color='darkslategray', label='$\sigma$ data', marker='s', mfc='None', linewidth=0.6)
ax1a.errorbar(x0, y0*norm, yerr*norm, color='darkslategray', label='$\sigma$ data', marker='s', mfc='None', linewidth=0.6)

ax2a.set_ylim(0.00,1.2/45)
ax2a.set_xlim(-0.2,0.21)

ax2.set_ylim(0.00,1.2/45)
ax2.set_xlim(1.25,2.5)
ax2.legend(loc='upper center', ncols=2)

ax1a.set_ylim(0.00,1.2/45)
ax1a.set_xlim(-0.2,0.21)

ax1.set_ylim(0.00,1.2/45)
ax1.set_xlim(1.25,2.5)
ax1.legend(loc='upper center', ncols=2)


# Plot the orbital occupancies in the third panel
evals = xsplit['rixs_ana_results']['evals']
t2g = xsplit['rixs_ana_results']['d_t2g']
eg = xsplit['rixs_ana_results']['d_eg']

ax3.plot(evals, t2g, marker='d',  label=r'$t_{2g}$', linewidth=0.6)
ax3.plot(evals, eg, marker='o',  label=r'$e_g$', linewidth=0.6)
ax3.plot(evals, t2g+eg, marker='o',  label='d ($t_{2g}+e_g$)', linewidth=0.6)
ax3a.plot(evals, t2g, marker='d',  label=r'$t_{2g}$', linewidth=0.6)
ax3a.plot(evals, eg, marker='o',  label=r'$e_g$', linewidth=0.6)
ax3a.plot(evals, t2g+eg, marker='o',  label='d ($t_{2g}+e_g$)', linewidth=0.6)

ax3.legend(loc='upper center', ncols=3)
ax3.set_ylim(0, 7)
ax3.set_xlim(1.25,2.5)

ax3a.set_ylim(0, 7)
ax3a.set_xlim(-0.2,0.21)

# Plot the total spin in the fourth panel
L2 = xsplit['rixs_ana_results']['L2_Cr_val']
S2 = xsplit['rixs_ana_results']['S2_Cr_val']

ax4.plot(evals, S2, label=r'$\langle S^2 \rangle$', marker='o', linewidth=0.6)
ax4.plot(evals, L2, label=r'$\langle L^2 \rangle$', marker='o', linewidth=0.6)
ax4a.plot(evals, S2, label=r'$\langle S^2 \rangle$', marker='o', linewidth=0.6)
ax4a.plot(evals, L2, label=r'$\langle L^2 \rangle$', marker='o', linewidth=0.6)

ax4.legend()
ax4.legend(loc='upper center', ncols=2)
ax4.set_ylim(0, 22)
ax4.set_xlim(1.25,2.5)
ax4a.set_ylim(0, 22)
ax4a.set_xlim(-0.2,0.21)

# Label the axes
ax1.tick_params(labelbottom = False, left=False, labelleft=False ) 
ax2.tick_params(labelbottom = False, left=False, labelleft=False ) 
ax3.tick_params(labelbottom = False, left=False, labelleft=False ) 
ax4.tick_params( left=False, labelleft=False ) 

ax1a.tick_params(labelbottom = False ) 
ax2a.tick_params(labelbottom = False ) 
ax3a.tick_params(labelbottom = False ) 

ax1a.spines['right'].set_visible(False)
ax1.spines['left'].set_visible(False)
ax2a.spines['right'].set_visible(False)
ax2.spines['left'].set_visible(False)
ax3a.spines['right'].set_visible(False)
ax3.spines['left'].set_visible(False)
ax4a.spines['right'].set_visible(False)
ax4.spines['left'].set_visible(False)

ax1a.set_ylabel('Intensity (counts/s)')
ax2a.set_ylabel('Intensity (arb. units)')
ax3a.set_ylabel('Orbital\noccupancy (electrons)')
ax4a.set_ylabel('Angular\nmomentum ($\hbar^2$)')
ax4.set_xlabel('Energy loss (eV)')

ax1a.yaxis.set_minor_locator(ticker.MultipleLocator(0.005))
ax2a.yaxis.set_minor_locator(ticker.MultipleLocator(0.005))
ax3a.yaxis.set_minor_locator(ticker.MultipleLocator(1.25))
ax4a.yaxis.set_minor_locator(ticker.MultipleLocator(5))

ax1.xaxis.set_minor_locator(ticker.MultipleLocator(0.125))
ax2.xaxis.set_minor_locator(ticker.MultipleLocator(0.125))
ax3.xaxis.set_minor_locator(ticker.MultipleLocator(0.125))
ax4.xaxis.set_minor_locator(ticker.MultipleLocator(0.125))
ax4.set_xticks(np.array([1.5, 1.75, 2, 2.25, 2.5]))

ax1a.xaxis.set_minor_locator(ticker.MultipleLocator(0.1))
ax2a.xaxis.set_minor_locator(ticker.MultipleLocator(0.1))
ax3a.xaxis.set_minor_locator(ticker.MultipleLocator(0.1))
ax4a.xaxis.set_minor_locator(ticker.MultipleLocator(0.1))

ax1a.axvline(x=0.2, ls='--', color='k', linewidth=0.5)
ax2a.axvline(x=0.2, ls='--', color='k', linewidth=0.5)
ax3a.axvline(x=0.2, ls='--', color='k', linewidth=0.5)
ax4a.axvline(x=0.2, ls='--', color='k', linewidth=0.5)

ax1.axvline(x=1.25, ls='--', color='k', linewidth=0.5)
ax2.axvline(x=1.25, ls='--', color='k', linewidth=0.5)
ax3.axvline(x=1.25, ls='--', color='k', linewidth=0.5)
ax4.axvline(x=1.25, ls='--', color='k', linewidth=0.5)

for ax in [ax1, ax2, ax3, ax4]:
    ax.fill_betweenx([-10, 30], 1.4, 1.73, color='blue', alpha=0.1, edgecolor='None')
    ax.fill_betweenx([-10, 30], 1.81, 1.95, color='blue', alpha=0.1, edgecolor='None')
    ax.fill_betweenx([-10, 30], 2.14, 2.4, color='blue', alpha=0.1, edgecolor='None')


ax1.text(1.55, 0.016, '1')
ax1.text(1.863, 0.016, '2')
ax1.text(2.25, 0.016, '3')

fig.text(0.005, -0.01+dd1+4*dh+2*hh+2*hh1, 'a', fontsize=7)
fig.text(0.005, -0.01+dd1+3*dh+hh+2*hh1, 'b', fontsize=7)
fig.text(0.005, -0.01+dd1+2*dh+2*hh1, 'c', fontsize=7)
fig.text(0.005, -0.01+dd1+dh+hh1, 'd', fontsize=7)

plt.show()
